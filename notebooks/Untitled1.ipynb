# %%
 {'id': 'e6e0baee7fc87d72e3833cbdd16fcf8a',
  'sport_key': 'baseball_ncaa',
  'sport_title': 'NCAA Baseball',
  'commence_time': '2025-06-02T22:05:47Z',
  'home_team': 'Ole Miss Rebels',
  'away_team': 'Murray St Racers',
  'bookmakers': [{'key': 'draftkings',
    'title': 'DraftKings',
    'last_update': '2025-06-02T23:42:49Z',
    'markets': [{'key': 'h2h',
      'last_update': '2025-06-02T23:42:49Z',
      'outcomes': [{'name': 'Murray St Racers', 'price': -475},
       {'name': 'Ole Miss Rebels', 'price': 325}]}]},

# %%
import requests
import pandas as pd

url = "https://api.the-odds-api.com/v4/sports/upcoming/odds/?regions=us&markets=h2h&oddsFormat=american&apiKey=c536f6aea3e12aefcaa79e8cf6279528"
response = requests.get(url)
odds = response.json()

df = pd.DataFrame(odds)
df
# Out:
#                                   id                sport_key  \
# 0   6c7c6ee439c22b8440724a2c87af4589    soccer_brazil_serie_b
# 1   50d5daa4c59f21a20f2b88ee59147be4  soccer_chile_campeonato
# 2   e6e0baee7fc87d72e3833cbdd16fcf8a            baseball_ncaa
# 3   d3c58f2f32e2c96ddb0f95aadb250648            baseball_ncaa
# 4   87ca0f2955d8b7a932dc43e58926eff1            baseball_ncaa
# 5   21e0dd9d71f12585caf1abc0b52337ea             baseball_mlb
# 6   93ae5fcbf33448d9a7134c79e8e7d675             baseball_mlb
# 7   22f8abc22cc9e459b39e91d84d06c0bf             baseball_mlb
# 8   0ae61d1233277840c2d817a3d874a44f             baseball_mlb
# 9   9257de943834310d3807b59932d35ce4            icehockey_ahl
# 10  5dbae070c397b361c705687a779fcc7a    soccer_brazil_serie_b
# 11  6a7ccb33a7c4091e18038c5eea627c2d            baseball_ncaa
# 12  9e0dc29ef14e39a566774b0611051ce2            baseball_ncaa
# 13  5b3c9550e26f358c2622a85ea807c9de             baseball_mlb
# ...

# %%
import requests
import pandas as pd

url = "https://api.the-odds-api.com/v4/sports/upcoming/odds/?regions=us&markets=h2h&oddsFormat=american&apiKey=c536f6aea3e12aefcaa79e8cf6279528"
response = requests.get(url)
odds = response.json()

df = pd.DataFrame(odds)

#&regions=us&markets=h2h&dateFormat={dateFormat}&oddsFormat={oddsFormat}"
#&regions=us&markets=h2h&oddsFormat=american"
url = "https://api.the-odds-api.com/v4/sports/baseball_mlb/events/22f8abc22cc9e459b39e91d84d06c0bf/odds?apiKey=c536f6aea3e12aefcaa79e8cf6279528&regions=us&markets=h2h&oddsFormat=american"
response = requests.get(url)
odds = response.json()
odds
#df = pd.DataFrame(odds)


#df
# Out:
# {'id': '22f8abc22cc9e459b39e91d84d06c0bf',
#  'sport_key': 'baseball_mlb',
#  'sport_title': 'MLB',
#  'commence_time': '2025-06-02T23:11:00Z',
#  'home_team': 'Cincinnati Reds',
#  'away_team': 'Milwaukee Brewers',
#  'bookmakers': [{'key': 'fanduel',
#    'title': 'FanDuel',
#    'markets': [{'key': 'h2h',
#      'last_update': '2025-06-02T23:51:24Z',
#      'outcomes': [{'name': 'Cincinnati Reds', 'price': -128},
#       {'name': 'Milwaukee Brewers', 'price': 100}]}]},
#   {'key': 'draftkings',
#    'title': 'DraftKings',
#    'markets': [{'key': 'h2h',
#      'last_update': '2025-06-02T23:51:28Z',
#      'outcomes': [{'name': 'Cincinnati Reds', 'price': -125},
#       {'name': 'Milwaukee Brewers', 'price': -105}]}]},
#   {'key': 'betmgm',
#    'title': 'BetMGM',
#    'markets': [{'key': 'h2h',
#      'last_update': '2025-06-02T23:51:07Z',
#      'outcomes': [{'name': 'Cincinnati Reds', 'price': -125},
#       {'name': 'Milwaukee Brewers', 'price': 100}]}]},
#   {'key': 'bovada',
# ...
